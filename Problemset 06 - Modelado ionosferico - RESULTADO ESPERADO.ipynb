# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
bogtnavfile = "data/bogt0010.15n"
bogtobsfile = "data/bogt0010.15o"

leijnavfile = "data/leij0010.15n"
leijobsfile = "data/leij0010.15o"

alrtnavfile = "data/alrt0010.15n"
alrtobsfile = "data/alrt0010.15o"

madrnavfile = "data/madr0010.15n"
madrobsfile = "data/madr0010.15o"

lhaznavfile = "data/lhaz0010.15n"
lhazobsfile = "data/lhaz0010.15o"

# %% [markdown]
# ## <font style="color:red"> Ejercicio 1: Implementa el modelo de Klobuchar según la descripción [aquí](http://www.navipedia.net/index.php/Klobuchar_Ionospheric_Model).
#
# Recuerda que el modelo te da el tiempo del retraso ionosférico en segundos, multiplícalo por la velocidad de la luz (299792458 Km/h) para tenerlo en metros y poder aplicarlo directamente sobre el observable de pseudorando.
#
# Para comprobarlo, usa los Alphas y Betas que viene en el fichero de navegación de la estación LEIJ 1/1/2015 con el siguiente código (no todas las estaciones incluyen siempre estos parámetros en los ficheros publicados):
#
#             nh=gpstk.readRinexNav("data/leij0010.15n")[0]
#             alphas = nh.ionAlpha
#             betas  = nh.ionBeta
#
# y grafica los retrasos ionosféricos medidos por doble frecuencia y los predichos por Klobuchar
#
# - para todas las observaciones
# - para los satélites 3,11,19 y 21

# %%
# Out:
# ['C1' 'C2' 'C5' 'P1' 'P2' 'L1' 'L2' 'L5' 'D1' 'D2' 'D5' 'S1' 'S2' 'S5']
# [ 3898736.7     855345.04   4958372.252]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900
# number of observations 2767
# positioning error avg 23.13 std 8.25
# observations filtered by elevation 0.8%

# %% [markdown]
# ## <font style="color:red"> Ejercicio 2: Realiza el ejercicio 1 para las estaciones BOGT y ALRT para el 1/1/2015

# %%
# Out:
# ['L1' 'L2' 'P1' 'P2' 'C1' 'S1' 'S2']
# [ 1744399.0397 -6116037.5577   512731.7532]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400
# number of observations 2277
# positioning error avg 16.60 std 8.43

# %%
# Out:
# ['L1' 'L2' 'C1' 'P2' 'P1' 'S1' 'S2']
# [  388042.754   -740382.3996  6302001.851 ]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2716
# positioning error avg 22.53 std 10.04

# %% [markdown]
# ## <font style="color:red"> Ejercicio 3: Calcula el error medio en el posicionamiento y la desviación estandar para la estación LEIJ 1/1/15
#
# - Con una frecuencia
# - Con doble frecuancia
# - Con una frecuencia aplicando el modelo de Klobuchar, usando los $\alpha$'s y $\beta$'s incluidos en el propio fichero de navegación de la misma estación

# %%
plot_pos_error(leijobsfile, leijnavfile, no_plots=True)
# Out:
# ['C1' 'C2' 'C5' 'P1' 'P2' 'L1' 'L2' 'L5' 'D1' 'D2' 'D5' 'S1' 'S2' 'S5']
# [ 3898736.7     855345.04   4958372.252]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900
# number of observations 2767
# positioning error avg 23.13 std 8.25
# observations filtered by elevation 0.8%

# %%
plot_pos_error(leijobsfile, leijnavfile, ionocorr=True, no_plots=True)
# Out:
# ['C1' 'C2' 'C5' 'P1' 'P2' 'L1' 'L2' 'L5' 'D1' 'D2' 'D5' 'S1' 'S2' 'S5']
# [ 3898736.7     855345.04   4958372.252]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900
# number of observations 2766
# positioning error avg 21.35 std 7.71
# observations filtered by elevation 0.8%

# %%
plot_pos_error(leijobsfile, leijnavfile, klobuchar=True, no_plots=True, alphas=alpha, betas=beta)
# Out:
# ['C1' 'C2' 'C5' 'P1' 'P2' 'L1' 'L2' 'L5' 'D1' 'D2' 'D5' 'S1' 'S2' 'S5']
# [ 3898736.7     855345.04   4958372.252]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900
# number of observations 2767
# positioning error avg 19.94 std 7.97
# observations filtered by elevation 0.8%

# %% [markdown]
# ## <font style="color:red"> Ejercicio 4: Realiza el ejercicio 3 con las estaciones BOGT, MADR, ALRT y LHAZ, siempre usando los $\alpha$'s y $\beta$'s del fichero de navegación de la estación LEIJ

# %% [markdown]
# ### Estación BOGT

# %%
plot_pos_error(bogtobsfile, bogtnavfile, no_plots=True)
# Out:
# ['L1' 'L2' 'P1' 'P2' 'C1' 'S1' 'S2']
# [ 1744399.0397 -6116037.5577   512731.7532]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400
# number of observations 2277
# positioning error avg 16.60 std 8.43

# %%
plot_pos_error(bogtobsfile, bogtnavfile, ionocorr=True, no_plots=True)
# Out:
# ['L1' 'L2' 'P1' 'P2' 'C1' 'S1' 'S2']
# [ 1744399.0397 -6116037.5577   512731.7532]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400
# number of observations 2277
# positioning error avg 7.52 std 3.72

# %%
plot_pos_error(bogtobsfile, bogtnavfile, klobuchar=True, no_plots=True, alphas=alpha, betas=beta)
# Out:
# ['L1' 'L2' 'P1' 'P2' 'C1' 'S1' 'S2']
# [ 1744399.0397 -6116037.5577   512731.7532]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400
# number of observations 2277
# positioning error avg 13.86 std 8.04

# %% [markdown]
# ### Estación MADR

# %%
plot_pos_error(madrobsfile, madrnavfile, no_plots=True)
# Out:
# ['L1' 'L2' 'L5' 'C1' 'P1' 'P2' 'C5' 'S1' 'S2' 'S5']
# [ 4849202.394   -360328.9929  4114913.1862]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2643
# positioning error avg 16.10 std 6.42

# %%
plot_pos_error(madrobsfile, madrnavfile, ionocorr=True, no_plots=True)
# Out:
# ['L1' 'L2' 'L5' 'C1' 'P1' 'P2' 'C5' 'S1' 'S2' 'S5']
# [ 4849202.394   -360328.9929  4114913.1862]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2643
# positioning error avg 13.62 std 5.33

# %%
plot_pos_error(madrobsfile, madrnavfile, klobuchar=True, no_plots=True, alphas=alpha, betas=beta)
# Out:
# ['L1' 'L2' 'L5' 'C1' 'P1' 'P2' 'C5' 'S1' 'S2' 'S5']
# [ 4849202.394   -360328.9929  4114913.1862]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2643
# positioning error avg 13.15 std 5.99

# %% [markdown]
# ### Estación ALRT

# %%
plot_pos_error(alrtobsfile, alrtnavfile, no_plots=True)
# Out:
# ['L1' 'L2' 'C1' 'P2' 'P1' 'S1' 'S2']
# [  388042.754   -740382.3996  6302001.851 ]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2716
# positioning error avg 22.53 std 10.04

# %%
plot_pos_error(alrtobsfile, alrtnavfile, ionocorr=True, no_plots=True)
# Out:
# ['L1' 'L2' 'C1' 'P2' 'P1' 'S1' 'S2']
# [  388042.754   -740382.3996  6302001.851 ]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2716
# positioning error avg 21.25 std 9.11

# %%
plot_pos_error(alrtobsfile, alrtnavfile, klobuchar=True, no_plots=True, alphas=alpha, betas=beta)
# Out:
# ['L1' 'L2' 'C1' 'P2' 'P1' 'S1' 'S2']
# [  388042.754   -740382.3996  6302001.851 ]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2716
# positioning error avg 18.88 std 9.92

# %% [markdown]
# ### Estación LHAZ

# %%
plot_pos_error(lhazobsfile, lhaznavfile, no_plots=True)
# Out:
# ['C1' 'P1' 'P2' 'L1' 'L2' 'D1' 'D2' 'S1' 'S2']
# [ -106942.17  5549274.75  3139222.27]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2544
# positioning error avg 8.99 std 5.17
# observations filtered by elevation 1.0%

# %%
plot_pos_error(lhazobsfile, lhaznavfile, ionocorr=True, no_plots=True)
# Out:
# ['C1' 'P1' 'P2' 'L1' 'L2' 'D1' 'D2' 'S1' 'S2']
# [ -106942.17  5549274.75  3139222.27]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2544
# positioning error avg 4.83 std 1.99
# observations filtered by elevation 1.0%

# %%
plot_pos_error(lhazobsfile, lhaznavfile, klobuchar=True, no_plots=True, alphas=alpha, betas=beta)
# Out:
# ['C1' 'P1' 'P2' 'L1' 'L2' 'D1' 'D2' 'S1' 'S2']
# [ -106942.17  5549274.75  3139222.27]
# observations processed 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
# number of observations 2544
# positioning error avg 7.40 std 4.40
# observations filtered by elevation 1.0%
